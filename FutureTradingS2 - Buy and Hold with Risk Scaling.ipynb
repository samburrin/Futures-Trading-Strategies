# %%
import pandas as pd
import numpy as np
from datetime import datetime
import matplotlib.pyplot as plt

# %%
df_2024 = pd.read_parquet(r"C:\Users\Guest_Account\Desktop\Futures Strategies\Futures_2024.parquet", engine='pyarrow')
df_2023 = pd.read_parquet(r"C:\Users\Guest_Account\Desktop\Futures Strategies\Futures_2023.parquet", engine='pyarrow')

# %%
df = pd.concat([df_2023, df_2024])
df = df[[col for col in df.columns if 'Close' in col]]
price = df['AUROPHARMA_Close']
prices = price.to_frame(name=' AUROPHARMA Price')
prices.index = pd.to_datetime(prices.index)
prices.index.name = 'Datetime'
prices = prices.resample('D').last()
prices.dropna(inplace=True)

# %%
#Plan:
#Start with four contracts, and 1000000 capital
#Every day, calculate the new standard devation of returns up to that point.
#Every day, calculate N using formula.
#This is our signal, if our current N != int(New N), then buy or sell accordingly and adjust capital..


class FutureStrategyTwo:
    def __init__(self, price, initial_capital= 1000000, target_risk = 20):
        self.prices = prices
        self.mult = 550 #Found in other doc
        self.cash = initial_capital 
        self.targetrisk = target_risk #%, as found in book.
        self.position = 4
        self.trade_log = []
        self.capital_series = pd.Series(index=prices.index)
        self.capital_series.iloc[1] = initial_capital
        self.position_series = pd.Series(index=prices.index)
        


    def calculate_returns_and_std_dev(self):
        returns = (self.prices.diff() / self.prices.shift(1)) * 100
        sd_returns = returns.expanding().std()
        sd_returns.index = self.prices.index
        
        return sd_returns*16

        
    def calculate_N(self, timestamp, sd_returns):
        price = self.prices.loc[timestamp]
        num_of_contracts = (self.cash * self.targetrisk) / (price * self.mult * sd_returns.loc[timestamp])
        
        return int(num_of_contracts)   

    def buy_contract(self, timestamp, contracts):
        price = self.prices.loc[timestamp]
        self.position += contracts
        self.cash -= contracts * price * self.mult
        self.trade_log.append((timestamp, 'BUY', contracts, price))
        self.capital_series[timestamp] = self.capital_series.shift(1).loc[timestamp] + (price - self.prices.shift(1).loc[timestamp])*self.position*self.mult
        self.position_series[timestamp] = self.position

    def sell_contract(self, timestamp, contracts):
        price = self.prices.loc[timestamp]
        self.position -= contracts
        self.cash += contracts * price * self.mult
        self.trade_log.append((timestamp, 'SELL', contracts, price))
        self.capital_series[timestamp] = self.capital_series.shift(1).loc[timestamp] + (price - self.prices.shift(1).loc[timestamp])*self.position*self.mult
        self.position_series[timestamp] = self.position

    def no_trade(self, timestamp, contracts):
        price = self.prices.loc[timestamp]
        self.position += contracts
        self.cash -= contracts * price * self.mult
        self.trade_log.append((timestamp, 'HOLD POSITION', price))
        self.capital_series[timestamp] = self.capital_series.shift(1).loc[timestamp] + (price - self.prices.shift(1).loc[timestamp])*self.position*self.mult
        self.position_series[timestamp] = self.position
    
    def trade(self, timestamp, sd_returns):
    
        num_of_contracts =  self.calculate_N(timestamp, sd_returns)
        contracts_to_trade = num_of_contracts - self.position


        if contracts_to_trade > 0:
            self.buy_contract(timestamp, contracts_to_trade)

        elif contracts_to_trade < 0:
            self.sell_contract(timestamp, -(contracts_to_trade))
        
        elif contracts_to_trade == 0:
            self.no_trade(timestamp, -(contracts_to_trade))

         

    
    def get_capital_progression(self):
        return self.capital_series

    def get_trade_log(self):
        return self.trade_log
    
    def get_position_series(self):
        return self.position_series
    
strategy = FutureStrategyTwo(prices)


sd_returns = strategy.calculate_returns_and_std_dev()

for timestamp in prices.index[2:]:  
    strategy.trade(timestamp, sd_returns)

cap_progression = strategy.get_capital_progression()[1:]
print("Capital Progression Over Time:")
print(cap_progression)

trade_log = strategy.get_trade_log()
print("Trade Log:")
print(trade_log)

position_series = strategy.get_position_series()
# Out:
# C:\Users\Guest_Account\AppData\Local\Temp\ipykernel_21692\1717766301.py:34: FutureWarning: Calling int on a single element Series is deprecated and will raise a TypeError in the future. Use int(ser.iloc[0]) instead
#   return int(num_of_contracts)
# C:\Users\Guest_Account\AppData\Local\Temp\ipykernel_21692\1717766301.py:49: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   self.capital_series[timestamp] = self.capital_series.shift(1).loc[timestamp] + (price - self.prices.shift(1).loc[timestamp])*self.position*self.mult
# C:\Users\Guest_Account\AppData\Local\Temp\ipykernel_21692\1717766301.py:41: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   self.capital_series[timestamp] = self.capital_series.shift(1).loc[timestamp] + (price - self.prices.shift(1).loc[timestamp])*self.position*self.mult
# C:\Users\Guest_Account\AppData\Local\Temp\ipykernel_21692\1717766301.py:57: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   self.capital_series[timestamp] = self.capital_series.shift(1).loc[timestamp] + (price - self.prices.shift(1).loc[timestamp])*self.position*self.mult
# Capital Progression Over Time:
# Datetime
# 2023-01-03    1000000.0
# 2023-01-04     996370.0
# 2023-01-05    1006407.5
# 2023-01-06    1002530.0
# 2023-01-09    1004015.0
#                 ...
# 2024-06-26    1736862.5
# 2024-06-27    1741317.5
# 2024-06-28    1749980.0
# 2024-07-01    1754600.0
# 2024-07-02    1753720.0
# Length: 368, dtype: float64
# Trade Log:
# [(Timestamp('2023-01-04 00:00:00'), 'SELL', 1, AUROPHARMA Price    442.6
# Name: 2023-01-04 00:00:00, dtype: float64), (Timestamp('2023-01-05 00:00:00'), 'BUY', 2, AUROPHARMA Price    446.25
# Name: 2023-01-05 00:00:00, dtype: float64), (Timestamp('2023-01-06 00:00:00'), 'SELL', 2, AUROPHARMA Price    443.9
# Name: 2023-01-06 00:00:00, dtype: float64), (Timestamp('2023-01-09 00:00:00'), 'BUY', 3, AUROPHARMA Price    444.35
# Name: 2023-01-09 00:00:00, dtype: float64), (Timestamp('2023-01-10 00:00:00'), 'SELL', 4, AUROPHARMA Price    452.7
# Name: 2023-01-10 00:00:00, dtype: float64), (Timestamp('2023-01-11 00:00:00'), 'BUY', 5, AUROPHARMA Price    449.7
# Name: 2023-01-11 00:00:00, dtype: float64), (Timestamp('2023-01-12 00:00:00'), 'SELL', 6, AUROPHARMA Price    447.8
# Name: 2023-01-12 00:00:00, dtype: float64), (Timestamp('2023-01-13 00:00:00'), 'BUY', 5, AUROPHARMA Price    436.2
# Name: 2023-01-13 00:00:00, dtype: float64), (Timestamp('2023-01-16 00:00:00'), 'SELL', 5, AUROPHARMA Price    447.65
# Name: 2023-01-16 00:00:00, dtype: float64), (Timestamp('2023-01-17 00:00:00'), 'BUY', 5, AUROPHARMA Price    443.7
# Name: 2023-01-17 00:00:00, dtype: float64), (Timestamp('2023-01-18 00:00:00'), 'SELL', 5, AUROPHARMA Price    445.7
# Name: 2023-01-18 00:00:00, dtype: float64), (Timestamp('2023-01-19 00:00:00'), 'BUY', 5, AUROPHARMA Price    445.3
# Name: 2023-01-19 00:00:00, dtype: float64), (Timestamp('2023-01-20 00:00:00'), 'SELL', 4, AUROPHARMA Price    443.45
# Name: 2023-01-20 00:00:00, dtype: float64), (Timestamp('2023-01-23 00:00:00'), 'BUY', 4, AUROPHARMA Price    446.3
# Name: 2023-01-23 00:00:00, dtype: float64), (Timestamp('2023-01-24 00:00:00'), 'SELL', 4, AUROPHARMA Price    437.45
# Name: 2023-01-24 00:00:00, dtype: float64), (Timestamp('2023-01-25 00:00:00'), 'BUY', 2, AUROPHARMA Price    417.2
# Name: 2023-01-25 00:00:00, dtype: float64), (Timestamp('2023-01-27 00:00:00'), 'SELL', 1, AUROPHARMA Price    418.5
# Name: 2023-01-27 00:00:00, dtype: float64), (Timestamp('2023-01-30 00:00:00'), 'BUY', 1, AUROPHARMA Price    414.4
# Name: 2023-01-30 00:00:00, dtype: float64), (Timestamp('2023-01-31 00:00:00'), 'SELL', 1, AUROPHARMA Price    412.7
# Name: 2023-01-31 00:00:00, dtype: float64), (Timestamp('2023-02-01 00:00:00'), 'BUY', 1, AUROPHARMA Price    414.15
# Name: 2023-02-01 00:00:00, dtype: float64), (Timestamp('2023-02-02 00:00:00'), 'SELL', 1, AUROPHARMA Price    411.65
# Name: 2023-02-02 00:00:00, dtype: float64), (Timestamp('2023-02-03 00:00:00'), 'BUY', 1, AUROPHARMA Price    403.95
# Name: 2023-02-03 00:00:00, dtype: float64), (Timestamp('2023-02-06 00:00:00'), 'SELL', 1, AUROPHARMA Price    415.25
# Name: 2023-02-06 00:00:00, dtype: float64), (Timestamp('2023-02-07 00:00:00'), 'BUY', 1, AUROPHARMA Price    421.95
# Name: 2023-02-07 00:00:00, dtype: float64), (Timestamp('2023-02-08 00:00:00'), 'SELL', 2, AUROPHARMA Price    446.5
# Name: 2023-02-08 00:00:00, dtype: float64), (Timestamp('2023-02-09 00:00:00'), 'BUY', 2, AUROPHARMA Price    442.4
# Name: 2023-02-09 00:00:00, dtype: float64), (Timestamp('2023-02-10 00:00:00'), 'SELL', 2, AUROPHARMA Price    467.15
# Name: 2023-02-10 00:00:00, dtype: float64), (Timestamp('2023-02-13 00:00:00'), 'BUY', 1, AUROPHARMA Price    470.55
# Name: 2023-02-13 00:00:00, dtype: float64), (Timestamp('2023-02-14 00:00:00'), 'HOLD POSITION', AUROPHARMA Price    471.2
# Name: 2023-02-14 00:00:00, dtype: float64), (Timestamp('2023-02-15 00:00:00'), 'HOLD POSITION', AUROPHARMA Price    471.2
# Name: 2023-02-15 00:00:00, dtype: float64), (Timestamp('2023-02-16 00:00:00'), 'HOLD POSITION', AUROPHARMA Price    477.55
# Name: 2023-02-16 00:00:00, dtype: float64), (Timestamp('2023-02-17 00:00:00'), 'HOLD POSITION', AUROPHARMA Price    474.2
# Name: 2023-02-17 00:00:00, dtype: float64), (Timestamp('2023-02-20 00:00:00'), 'HOLD POSITION', AUROPHARMA Price    465.25
# Name: 2023-02-20 00:00:00, dtype: float64), (Timestamp('2023-02-21 00:00:00'), 'HOLD POSITION', AUROPHARMA Price    460.55
# Name: 2023-02-21 00:00:00, dtype: float64), (Timestamp('2023-02-22 00:00:00'), 'HOLD POSITION', AUROPHARMA Price    469.65
# Name: 2023-02-22 00:00:00, dtype: float64), (Timestamp('2023-02-23 00:00:00'), 'HOLD POSITION', AUROPHARMA Price    468.2
# Name: 2023-02-23 00:00:00, dtype: float64), (Timestamp('2023-02-24 00:00:00'), 'HOLD POSITION', AUROPHARMA Price    471.65
# Name: 2023-02-24 00:00:00, dtype: float64), (Timestamp('2023-02-27 00:00:00'), 'HOLD POSITION', AUROPHARMA Price    460.2
# Name: 2023-02-27 00:00:00, dtype: float64), (Timestamp('2023-02-28 00:00:00'), 'HOLD POSITION', AUROPHARMA Price    463.9
# Name: 2023-02-28 00:00:00, dtype: float64), (Timestamp('2023-03-01 00:00:00'), 'HOLD POSITION', AUROPHARMA Price    465.85
# Name: 2023-03-01 00:00:00, dtype: float64), (Timestamp('2023-03-02 00:00:00'), 'HOLD POSITION', AUROPHARMA Price    463.85
# Name: 2023-03-02 00:00:00, dtype: float64), (Timestamp('2023-03-03 00:00:00'), 'HOLD POSITION', AUROPHARMA Price    462.8
# Name: 2023-03-03 00:00:00, dtype: float64), (Timestamp('2023-03-06 00:00:00'), 'HOLD POSITION', AUROPHARMA Price    468.75
# Name: 2023-03-06 00:00:00, dtype: float64), (Timestamp('2023-03-08 00:00:00'), 'HOLD POSITION', AUROPHARMA Price    463.65
# Name: 2023-03-08 00:00:00, dtype: float64), (Timestamp('2023-03-09 00:00:00'), 'HOLD POSITION', AUROPHARMA Price    458.4
# Name: 2023-03-09 00:00:00, dtype: float64), (Timestamp('2023-03-10 00:00:00'), 'HOLD POSITION', AUROPHARMA Price    455.35
# Name: 2023-03-10 00:00:00, dtype: float64), (Timestamp('2023-03-13 00:00:00'), 'HOLD POSITION', AUROPHARMA Price    448.8
# Name: 2023-03-13 00:00:00, dtype: float64), (Timestamp('2023-03-14 00:00:00'), 'HOLD POSITION', AUROPHARMA Price    453.45
# Name: 2023-03-14 00:00:00, dtype: float64), (Timestamp('2023-03-15 00:00:00'), 'HOLD POSITION', AUROPHARMA Price    459.25
# Name: 2023-03-15 00:00:00, dtype: float64), (Timestamp('2023-03-16 00:00:00'), 'HOLD POSITION', AUROPHARMA Price    479.0
# Name: 2023-03-16 00:00:00, dtype: float64), (Timestamp('2023-03-17 00:00:00'), 'HOLD POSITION', AUROPHARMA Price    479.75
# Name: 2023-03-17 00:00:00, dtype: float64), (Timestamp('2023-03-20 00:00:00'), 'HOLD POSITION', AUROPHARMA Price    477.35
# Name: 2023-03-20 00:00:00, dtype: float64), (Timestamp('2023-03-21 00:00:00'), 'HOLD POSITION', AUROPHARMA Price    469.5
# Name: 2023-03-21 00:00:00, dtype: float64), (Timestamp('2023-03-22 00:00:00'), 'HOLD POSITION', AUROPHARMA Price    480.2
# Name: 2023-03-22 00:00:00, dtype: float64), (Timestamp('2023-03-23 00:00:00'), 'HOLD POSITION', AUROPHARMA Price    486.05
# Name: 2023-03-23 00:00:00, dtype: float64), (Timestamp('2023-03-24 00:00:00'), 'HOLD POSITION', AUROPHARMA Price    500.1
# Name: 2023-03-24 00:00:00, dtype: float64), (Timestamp('2023-03-27 00:00:00'), 'HOLD POSITION', AUROPHARMA Price    510.65
# Name: 2023-03-27 00:00:00, dtype: float64), (Timestamp('2023-03-28 00:00:00'), 'HOLD POSITION', AUROPHARMA Price    510.25
# Name: 2023-03-28 00:00:00, dtype: float64), (Timestamp('2023-03-29 00:00:00'), 'HOLD POSITION', AUROPHARMA Price    510.7
# Name: 2023-03-29 00:00:00, dtype: float64), (Timestamp('2023-03-31 00:00:00'), 'HOLD POSITION', AUROPHARMA Price    520.1
# Name: 2023-03-31 00:00:00, dtype: float64), (Timestamp('2023-04-03 00:00:00'), 'HOLD POSITION', AUROPHARMA Price    522.0
# Name: 2023-04-03 00:00:00, dtype: float64), (Timestamp('2023-04-05 00:00:00'), 'HOLD POSITION', AUROPHARMA Price    526.05
# Name: 2023-04-05 00:00:00, dtype: float64), (Timestamp('2023-04-06 00:00:00'), 'HOLD POSITION', AUROPHARMA Price    539.0
# Name: 2023-04-06 00:00:00, dtype: float64), (Timestamp('2023-04-10 00:00:00'), 'HOLD POSITION', AUROPHARMA Price    541.4
# Name: 2023-04-10 00:00:00, dtype: float64), (Timestamp('2023-04-11 00:00:00'), 'HOLD POSITION', AUROPHARMA Price    544.95
# Name: 2023-04-11 00:00:00, dtype: float64), (Timestamp('2023-04-12 00:00:00'), 'SELL', 1, AUROPHARMA Price    562.85
# Name: 2023-04-12 00:00:00, dtype: float64), (Timestamp('2023-04-13 00:00:00'), 'BUY', 1, AUROPHARMA Price    566.5
# Name: 2023-04-13 00:00:00, dtype: float64), (Timestamp('2023-04-17 00:00:00'), 'HOLD POSITION', AUROPHARMA Price    559.9
# Name: 2023-04-17 00:00:00, dtype: float64), (Timestamp('2023-04-18 00:00:00'), 'SELL', 1, AUROPHARMA Price    577.8
# Name: 2023-04-18 00:00:00, dtype: float64), (Timestamp('2023-04-19 00:00:00'), 'BUY', 1, AUROPHARMA Price    589.25
# Name: 2023-04-19 00:00:00, dtype: float64), (Timestamp('2023-04-20 00:00:00'), 'SELL', 1, AUROPHARMA Price    581.9
# Name: 2023-04-20 00:00:00, dtype: float64), (Timestamp('2023-04-21 00:00:00'), 'BUY', 1, AUROPHARMA Price    587.5
# Name: 2023-04-21 00:00:00, dtype: float64), (Timestamp('2023-04-24 00:00:00'), 'SELL', 1, AUROPHARMA Price    589.6
# Name: 2023-04-24 00:00:00, dtype: float64), (Timestamp('2023-04-25 00:00:00'), 'BUY', 1, AUROPHARMA Price    601.0
# Name: 2023-04-25 00:00:00, dtype: float64), (Timestamp('2023-04-26 00:00:00'), 'SELL', 1, AUROPHARMA Price    612.8
# Name: 2023-04-26 00:00:00, dtype: float64), (Timestamp('2023-04-27 00:00:00'), 'BUY', 1, AUROPHARMA Price    618.55
# Name: 2023-04-27 00:00:00, dtype: float64), (Timestamp('2023-04-28 00:00:00'), 'SELL', 1, AUROPHARMA Price    617.5
# Name: 2023-04-28 00:00:00, dtype: float64), (Timestamp('2023-05-02 00:00:00'), 'BUY', 1, AUROPHARMA Price    622.55
# Name: 2023-05-02 00:00:00, dtype: float64), (Timestamp('2023-05-03 00:00:00'), 'SELL', 1, AUROPHARMA Price    618.7
# Name: 2023-05-03 00:00:00, dtype: float64), (Timestamp('2023-05-04 00:00:00'), 'BUY', 1, AUROPHARMA Price    616.1
# Name: 2023-05-04 00:00:00, dtype: float64), (Timestamp('2023-05-05 00:00:00'), 'SELL', 1, AUROPHARMA Price    602.55
# Name: 2023-05-05 00:00:00, dtype: float64), (Timestamp('2023-05-08 00:00:00'), 'BUY', 1, AUROPHARMA Price    621.0
# Name: 2023-05-08 00:00:00, dtype: float64), (Timestamp('2023-05-09 00:00:00'), 'SELL', 1, AUROPHARMA Price    617.25
# Name: 2023-05-09 00:00:00, dtype: float64), (Timestamp('2023-05-10 00:00:00'), 'BUY', 1, AUROPHARMA Price    620.2
# Name: 2023-05-10 00:00:00, dtype: float64), (Timestamp('2023-05-11 00:00:00'), 'SELL', 1, AUROPHARMA Price    610.3
# Name: 2023-05-11 00:00:00, dtype: float64), (Timestamp('2023-05-12 00:00:00'), 'BUY', 1, AUROPHARMA Price    609.65
# Name: 2023-05-12 00:00:00, dtype: float64), (Timestamp('2023-05-15 00:00:00'), 'SELL', 1, AUROPHARMA Price    614.5
# Name: 2023-05-15 00:00:00, dtype: float64), (Timestamp('2023-05-16 00:00:00'), 'BUY', 1, AUROPHARMA Price    641.35
# Name: 2023-05-16 00:00:00, dtype: float64), (Timestamp('2023-05-17 00:00:00'), 'SELL', 1, AUROPHARMA Price    619.1
# Name: 2023-05-17 00:00:00, dtype: float64), (Timestamp('2023-05-18 00:00:00'), 'BUY', 1, AUROPHARMA Price    598.05
# Name: 2023-05-18 00:00:00, dtype: float64), (Timestamp('2023-05-19 00:00:00'), 'SELL', 1, AUROPHARMA Price    589.8
# Name: 2023-05-19 00:00:00, dtype: float64), (Timestamp('2023-05-22 00:00:00'), 'BUY', 1, AUROPHARMA Price    604.9
# Name: 2023-05-22 00:00:00, dtype: float64), (Timestamp('2023-05-23 00:00:00'), 'SELL', 1, AUROPHARMA Price    603.55
# Name: 2023-05-23 00:00:00, dtype: float64), (Timestamp('2023-05-24 00:00:00'), 'BUY', 1, AUROPHARMA Price    606.45
# Name: 2023-05-24 00:00:00, dtype: float64), (Timestamp('2023-05-25 00:00:00'), 'SELL', 1, AUROPHARMA Price    608.25
# Name: 2023-05-25 00:00:00, dtype: float64), (Timestamp('2023-05-26 00:00:00'), 'BUY', 1, AUROPHARMA Price    618.0
# Name: 2023-05-26 00:00:00, dtype: float64), (Timestamp('2023-05-29 00:00:00'), 'SELL', 1, AUROPHARMA Price    615.95
# Name: 2023-05-29 00:00:00, dtype: float64), (Timestamp('2023-05-30 00:00:00'), 'HOLD POSITION', AUROPHARMA Price    654.15
# Name: 2023-05-30 00:00:00, dtype: float64), (Timestamp('2023-05-31 00:00:00'), 'HOLD POSITION', AUROPHARMA Price    663.2
# Name: 2023-05-31 00:00:00, dtype: float64), (Timestamp('2023-06-01 00:00:00'), 'HOLD POSITION', AUROPHARMA Price    660.1
# Name: 2023-06-01 00:00:00, dtype: float64), (Timestamp('2023-06-02 00:00:00'), 'HOLD POSITION', AUROPHARMA Price    666.0
# Name: 2023-06-02 00:00:00, dtype: float64), (Timestamp('2023-06-05 00:00:00'), 'HOLD POSITION', AUROPHARMA Price    663.95
# Name: 2023-06-05 00:00:00, dtype: float64), (Timestamp('2023-06-06 00:00:00'), 'HOLD POSITION', AUROPHARMA Price    667.55
# Name: 2023-06-06 00:00:00, dtype: float64), (Timestamp('2023-06-07 00:00:00'), 'HOLD POSITION', AUROPHARMA Price    678.0
# Name: 2023-06-07 00:00:00, dtype: float64), (Timestamp('2023-06-08 00:00:00'), 'HOLD POSITION', AUROPHARMA Price    671.7
# Name: 2023-06-08 00:00:00, dtype: float64), (Timestamp('2023-06-09 00:00:00'), 'BUY', 1, AUROPHARMA Price    669.35
# Name: 2023-06-09 00:00:00, dtype: float64), (Timestamp('2023-06-12 00:00:00'), 'SELL', 1, AUROPHARMA Price    667.25
# Name: 2023-06-12 00:00:00, dtype: float64), (Timestamp('2023-06-13 00:00:00'), 'HOLD POSITION', AUROPHARMA Price    683.65
# Name: 2023-06-13 00:00:00, dtype: float64), (Timestamp('2023-06-14 00:00:00'), 'HOLD POSITION', AUROPHARMA Price    671.55
# Name: 2023-06-14 00:00:00, dtype: float64), (Timestamp('2023-06-15 00:00:00'), 'HOLD POSITION', AUROPHARMA Price    685.5
# Name: 2023-06-15 00:00:00, dtype: float64), (Timestamp('2023-06-16 00:00:00'), 'HOLD POSITION', AUROPHARMA Price    684.7
# Name: 2023-06-16 00:00:00, dtype: float64), (Timestamp('2023-06-19 00:00:00'), 'HOLD POSITION', AUROPHARMA Price    681.55
# Name: 2023-06-19 00:00:00, dtype: float64), (Timestamp('2023-06-20 00:00:00'), 'HOLD POSITION', AUROPHARMA Price    683.0
# Name: 2023-06-20 00:00:00, dtype: float64), (Timestamp('2023-06-21 00:00:00'), 'HOLD POSITION', AUROPHARMA Price    683.85
# Name: 2023-06-21 00:00:00, dtype: float64), (Timestamp('2023-06-22 00:00:00'), 'BUY', 1, AUROPHARMA Price    671.7
# Name: 2023-06-22 00:00:00, dtype: float64), (Timestamp('2023-06-23 00:00:00'), 'SELL', 1, AUROPHARMA Price    700.9
# Name: 2023-06-23 00:00:00, dtype: float64), (Timestamp('2023-06-26 00:00:00'), 'HOLD POSITION', AUROPHARMA Price    720.55
# Name: 2023-06-26 00:00:00, dtype: float64), (Timestamp('2023-06-27 00:00:00'), 'HOLD POSITION', AUROPHARMA Price    718.0
# Name: 2023-06-27 00:00:00, dtype: float64), (Timestamp('2023-06-28 00:00:00'), 'HOLD POSITION', AUROPHARMA Price    736.05
# Name: 2023-06-28 00:00:00, dtype: float64), (Timestamp('2023-06-30 00:00:00'), 'HOLD POSITION', AUROPHARMA Price    732.05
# Name: 2023-06-30 00:00:00, dtype: float64), (Timestamp('2023-07-03 00:00:00'), 'HOLD POSITION', AUROPHARMA Price    718.05
# Name: 2023-07-03 00:00:00, dtype: float64), (Timestamp('2023-07-04 00:00:00'), 'HOLD POSITION', AUROPHARMA Price    719.15
# Name: 2023-07-04 00:00:00, dtype: float64), (Timestamp('2023-07-05 00:00:00'), 'HOLD POSITION', AUROPHARMA Price    734.6
# Name: 2023-07-05 00:00:00, dtype: float64), (Timestamp('2023-07-06 00:00:00'), 'HOLD POSITION', AUROPHARMA Price    767.95
# Name: 2023-07-06 00:00:00, dtype: float64), (Timestamp('2023-07-07 00:00:00'), 'HOLD POSITION', AUROPHARMA Price    751.0
# Name: 2023-07-07 00:00:00, dtype: float64), (Timestamp('2023-07-10 00:00:00'), 'HOLD POSITION', AUROPHARMA Price    740.0
# Name: 2023-07-10 00:00:00, dtype: float64), (Timestamp('2023-07-11 00:00:00'), 'HOLD POSITION', AUROPHARMA Price    740.6
# Name: 2023-07-11 00:00:00, dtype: float64), (Timestamp('2023-07-12 00:00:00'), 'HOLD POSITION', AUROPHARMA Price    736.35
# Name: 2023-07-12 00:00:00, dtype: float64), (Timestamp('2023-07-13 00:00:00'), 'HOLD POSITION', AUROPHARMA Price    729.35
# Name: 2023-07-13 00:00:00, dtype: float64), (Timestamp('2023-07-14 00:00:00'), 'HOLD POSITION', AUROPHARMA Price    742.2
# Name: 2023-07-14 00:00:00, dtype: float64), (Timestamp('2023-07-17 00:00:00'), 'HOLD POSITION', AUROPHARMA Price    740.95
# Name: 2023-07-17 00:00:00, dtype: float64), (Timestamp('2023-07-18 00:00:00'), 'HOLD POSITION', AUROPHARMA Price    757.0
# Name: 2023-07-18 00:00:00, dtype: float64), (Timestamp('2023-07-19 00:00:00'), 'HOLD POSITION', AUROPHARMA Price    752.1
# Name: 2023-07-19 00:00:00, dtype: float64), (Timestamp('2023-07-20 00:00:00'), 'HOLD POSITION', AUROPHARMA Price    774.0
# Name: 2023-07-20 00:00:00, dtype: float64), (Timestamp('2023-07-21 00:00:00'), 'HOLD POSITION', AUROPHARMA Price    782.2
# Name: 2023-07-21 00:00:00, dtype: float64), (Timestamp('2023-07-24 00:00:00'), 'HOLD POSITION', AUROPHARMA Price    787.5
# Name: 2023-07-24 00:00:00, dtype: float64), (Timestamp('2023-07-25 00:00:00'), 'HOLD POSITION', AUROPHARMA Price    789.05
# Name: 2023-07-25 00:00:00, dtype: float64), (Timestamp('2023-07-26 00:00:00'), 'HOLD POSITION', AUROPHARMA Price    793.5
# Name: 2023-07-26 00:00:00, dtype: float64), (Timestamp('2023-07-27 00:00:00'), 'HOLD POSITION', AUROPHARMA Price    840.95
# Name: 2023-07-27 00:00:00, dtype: float64), (Timestamp('2023-07-28 00:00:00'), 'HOLD POSITION', AUROPHARMA Price    843.8
# Name: 2023-07-28 00:00:00, dtype: float64), (Timestamp('2023-07-31 00:00:00'), 'HOLD POSITION', AUROPHARMA Price    831.45
# Name: 2023-07-31 00:00:00, dtype: float64), (Timestamp('2023-08-01 00:00:00'), 'HOLD POSITION', AUROPHARMA Price    825.1
# Name: 2023-08-01 00:00:00, dtype: float64), (Timestamp('2023-08-02 00:00:00'), 'HOLD POSITION', AUROPHARMA Price    823.05
# Name: 2023-08-02 00:00:00, dtype: float64), (Timestamp('2023-08-03 00:00:00'), 'HOLD POSITION', AUROPHARMA Price    845.85
# Name: 2023-08-03 00:00:00, dtype: float64), (Timestamp('2023-08-04 00:00:00'), 'HOLD POSITION', AUROPHARMA Price    846.35
# Name: 2023-08-04 00:00:00, dtype: float64), (Timestamp('2023-08-07 00:00:00'), 'HOLD POSITION', AUROPHARMA Price    872.5
# Name: 2023-08-07 00:00:00, dtype: float64), (Timestamp('2023-08-08 00:00:00'), 'HOLD POSITION', AUROPHARMA Price    870.6
# Name: 2023-08-08 00:00:00, dtype: float64), (Timestamp('2023-08-09 00:00:00'), 'HOLD POSITION', AUROPHARMA Price    882.5
# Name: 2023-08-09 00:00:00, dtype: float64), (Timestamp('2023-08-10 00:00:00'), 'HOLD POSITION', AUROPHARMA Price    876.5
# Name: 2023-08-10 00:00:00, dtype: float64), (Timestamp('2023-08-11 00:00:00'), 'HOLD POSITION', AUROPHARMA Price    867.05
# Name: 2023-08-11 00:00:00, dtype: float64), (Timestamp('2023-08-14 00:00:00'), 'HOLD POSITION', AUROPHARMA Price    876.0
# Name: 2023-08-14 00:00:00, dtype: float64), (Timestamp('2023-08-16 00:00:00'), 'HOLD POSITION', AUROPHARMA Price    878.75
# Name: 2023-08-16 00:00:00, dtype: float64), (Timestamp('2023-08-17 00:00:00'), 'HOLD POSITION', AUROPHARMA Price    869.0
# Name: 2023-08-17 00:00:00, dtype: float64), (Timestamp('2023-08-18 00:00:00'), 'HOLD POSITION', AUROPHARMA Price    857.7
# Name: 2023-08-18 00:00:00, dtype: float64), (Timestamp('2023-08-21 00:00:00'), 'HOLD POSITION', AUROPHARMA Price    858.0
# Name: 2023-08-21 00:00:00, dtype: float64), (Timestamp('2023-08-22 00:00:00'), 'HOLD POSITION', AUROPHARMA Price    841.5
# Name: 2023-08-22 00:00:00, dtype: float64), (Timestamp('2023-08-23 00:00:00'), 'HOLD POSITION', AUROPHARMA Price    838.9
# Name: 2023-08-23 00:00:00, dtype: float64), (Timestamp('2023-08-24 00:00:00'), 'HOLD POSITION', AUROPHARMA Price    832.75
# Name: 2023-08-24 00:00:00, dtype: float64), (Timestamp('2023-08-25 00:00:00'), 'HOLD POSITION', AUROPHARMA Price    827.8
# Name: 2023-08-25 00:00:00, dtype: float64), (Timestamp('2023-08-28 00:00:00'), 'HOLD POSITION', AUROPHARMA Price    829.2
# Name: 2023-08-28 00:00:00, dtype: float64), (Timestamp('2023-08-29 00:00:00'), 'HOLD POSITION', AUROPHARMA Price    829.0
# Name: 2023-08-29 00:00:00, dtype: float64), (Timestamp('2023-08-30 00:00:00'), 'HOLD POSITION', AUROPHARMA Price    833.35
# Name: 2023-08-30 00:00:00, dtype: float64), (Timestamp('2023-08-31 00:00:00'), 'HOLD POSITION', AUROPHARMA Price    826.05
# Name: 2023-08-31 00:00:00, dtype: float64), (Timestamp('2023-09-01 00:00:00'), 'HOLD POSITION', AUROPHARMA Price    828.25
# Name: 2023-09-01 00:00:00, dtype: float64), (Timestamp('2023-09-04 00:00:00'), 'HOLD POSITION', AUROPHARMA Price    827.05
# Name: 2023-09-04 00:00:00, dtype: float64), (Timestamp('2023-09-05 00:00:00'), 'HOLD POSITION', AUROPHARMA Price    861.5
# Name: 2023-09-05 00:00:00, dtype: float64), (Timestamp('2023-09-06 00:00:00'), 'HOLD POSITION', AUROPHARMA Price    869.0
# Name: 2023-09-06 00:00:00, dtype: float64), (Timestamp('2023-09-07 00:00:00'), 'HOLD POSITION', AUROPHARMA Price    867.15
# Name: 2023-09-07 00:00:00, dtype: float64), (Timestamp('2023-09-08 00:00:00'), 'HOLD POSITION', AUROPHARMA Price    860.7
# Name: 2023-09-08 00:00:00, dtype: float64), (Timestamp('2023-09-11 00:00:00'), 'HOLD POSITION', AUROPHARMA Price    871.8
# Name: 2023-09-11 00:00:00, dtype: float64), (Timestamp('2023-09-12 00:00:00'), 'HOLD POSITION', AUROPHARMA Price    870.8
# Name: 2023-09-12 00:00:00, dtype: float64), (Timestamp('2023-09-13 00:00:00'), 'HOLD POSITION', AUROPHARMA Price    903.0
# Name: 2023-09-13 00:00:00, dtype: float64), (Timestamp('2023-09-14 00:00:00'), 'HOLD POSITION', AUROPHARMA Price    899.0
# Name: 2023-09-14 00:00:00, dtype: float64), (Timestamp('2023-09-15 00:00:00'), 'HOLD POSITION', AUROPHARMA Price    900.75
# Name: 2023-09-15 00:00:00, dtype: float64), (Timestamp('2023-09-18 00:00:00'), 'HOLD POSITION', AUROPHARMA Price    897.05
# Name: 2023-09-18 00:00:00, dtype: float64), (Timestamp('2023-09-20 00:00:00'), 'HOLD POSITION', AUROPHARMA Price    893.75
# Name: 2023-09-20 00:00:00, dtype: float64), (Timestamp('2023-09-21 00:00:00'), 'HOLD POSITION', AUROPHARMA Price    880.45
# Name: 2023-09-21 00:00:00, dtype: float64), (Timestamp('2023-09-22 00:00:00'), 'HOLD POSITION', AUROPHARMA Price    871.05
# Name: 2023-09-22 00:00:00, dtype: float64), (Timestamp('2023-09-25 00:00:00'), 'HOLD POSITION', AUROPHARMA Price    873.5
# Name: 2023-09-25 00:00:00, dtype: float64), (Timestamp('2023-09-26 00:00:00'), 'HOLD POSITION', AUROPHARMA Price    859.65
# Name: 2023-09-26 00:00:00, dtype: float64), (Timestamp('2023-09-27 00:00:00'), 'HOLD POSITION', AUROPHARMA Price    879.6
# Name: 2023-09-27 00:00:00, dtype: float64), (Timestamp('2023-09-28 00:00:00'), 'HOLD POSITION', AUROPHARMA Price    874.7
# Name: 2023-09-28 00:00:00, dtype: float64), (Timestamp('2023-09-29 00:00:00'), 'HOLD POSITION', AUROPHARMA Price    921.85
# Name: 2023-09-29 00:00:00, dtype: float64), (Timestamp('2023-10-03 00:00:00'), 'HOLD POSITION', AUROPHARMA Price    913.95
# Name: 2023-10-03 00:00:00, dtype: float64), (Timestamp('2023-10-04 00:00:00'), 'HOLD POSITION', AUROPHARMA Price    891.0
# Name: 2023-10-04 00:00:00, dtype: float64), (Timestamp('2023-10-05 00:00:00'), 'HOLD POSITION', AUROPHARMA Price    886.2
# Name: 2023-10-05 00:00:00, dtype: float64), (Timestamp('2023-10-06 00:00:00'), 'HOLD POSITION', AUROPHARMA Price    910.55
# Name: 2023-10-06 00:00:00, dtype: float64), (Timestamp('2023-10-09 00:00:00'), 'HOLD POSITION', AUROPHARMA Price    919.85
# Name: 2023-10-09 00:00:00, dtype: float64), (Timestamp('2023-10-10 00:00:00'), 'HOLD POSITION', AUROPHARMA Price    911.65
# Name: 2023-10-10 00:00:00, dtype: float64), (Timestamp('2023-10-11 00:00:00'), 'HOLD POSITION', AUROPHARMA Price    908.15
# Name: 2023-10-11 00:00:00, dtype: float64), (Timestamp('2023-10-12 00:00:00'), 'HOLD POSITION', AUROPHARMA Price    925.3
# Name: 2023-10-12 00:00:00, dtype: float64), (Timestamp('2023-10-13 00:00:00'), 'HOLD POSITION', AUROPHARMA Price    926.5
# Name: 2023-10-13 00:00:00, dtype: float64), (Timestamp('2023-10-16 00:00:00'), 'HOLD POSITION', AUROPHARMA Price    917.0
# Name: 2023-10-16 00:00:00, dtype: float64), (Timestamp('2023-10-17 00:00:00'), 'HOLD POSITION', AUROPHARMA Price    915.0
# Name: 2023-10-17 00:00:00, dtype: float64), (Timestamp('2023-10-18 00:00:00'), 'HOLD POSITION', AUROPHARMA Price    904.45
# Name: 2023-10-18 00:00:00, dtype: float64), (Timestamp('2023-10-19 00:00:00'), 'HOLD POSITION', AUROPHARMA Price    889.9
# Name: 2023-10-19 00:00:00, dtype: float64), (Timestamp('2023-10-20 00:00:00'), 'HOLD POSITION', AUROPHARMA Price    869.8
# Name: 2023-10-20 00:00:00, dtype: float64), (Timestamp('2023-10-23 00:00:00'), 'HOLD POSITION', AUROPHARMA Price    874.3
# Name: 2023-10-23 00:00:00, dtype: float64), (Timestamp('2023-10-25 00:00:00'), 'HOLD POSITION', AUROPHARMA Price    863.35
# Name: 2023-10-25 00:00:00, dtype: float64), (Timestamp('2023-10-26 00:00:00'), 'HOLD POSITION', AUROPHARMA Price    861.95
# Name: 2023-10-26 00:00:00, dtype: float64), (Timestamp('2023-10-27 00:00:00'), 'HOLD POSITION', AUROPHARMA Price    861.55
# Name: 2023-10-27 00:00:00, dtype: float64), (Timestamp('2023-10-30 00:00:00'), 'HOLD POSITION', AUROPHARMA Price    865.05
# Name: 2023-10-30 00:00:00, dtype: float64), (Timestamp('2023-10-31 00:00:00'), 'HOLD POSITION', AUROPHARMA Price    854.0
# Name: 2023-10-31 00:00:00, dtype: float64), (Timestamp('2023-11-01 00:00:00'), 'HOLD POSITION', AUROPHARMA Price    860.0
# Name: 2023-11-01 00:00:00, dtype: float64), (Timestamp('2023-11-02 00:00:00'), 'HOLD POSITION', AUROPHARMA Price    862.5
# Name: 2023-11-02 00:00:00, dtype: float64), (Timestamp('2023-11-03 00:00:00'), 'HOLD POSITION', AUROPHARMA Price    855.0
# Name: 2023-11-03 00:00:00, dtype: float64), (Timestamp('2023-11-06 00:00:00'), 'HOLD POSITION', AUROPHARMA Price    881.0
# Name: 2023-11-06 00:00:00, dtype: float64), (Timestamp('2023-11-07 00:00:00'), 'HOLD POSITION', AUROPHARMA Price    903.55
# Name: 2023-11-07 00:00:00, dtype: float64), (Timestamp('2023-11-08 00:00:00'), 'HOLD POSITION', AUROPHARMA Price    939.3
# Name: 2023-11-08 00:00:00, dtype: float64), (Timestamp('2023-11-09 00:00:00'), 'HOLD POSITION', AUROPHARMA Price    952.0
# Name: 2023-11-09 00:00:00, dtype: float64), (Timestamp('2023-11-10 00:00:00'), 'HOLD POSITION', AUROPHARMA Price    978.5
# Name: 2023-11-10 00:00:00, dtype: float64), (Timestamp('2023-11-12 00:00:00'), 'HOLD POSITION', AUROPHARMA Price    977.25
# Name: 2023-11-12 00:00:00, dtype: float64), (Timestamp('2023-11-13 00:00:00'), 'HOLD POSITION', AUROPHARMA Price    975.0
# Name: 2023-11-13 00:00:00, dtype: float64), (Timestamp('2023-11-15 00:00:00'), 'HOLD POSITION', AUROPHARMA Price    966.95
# Name: 2023-11-15 00:00:00, dtype: float64), (Timestamp('2023-11-16 00:00:00'), 'HOLD POSITION', AUROPHARMA Price    978.65
# Name: 2023-11-16 00:00:00, dtype: float64), (Timestamp('2023-11-17 00:00:00'), 'HOLD POSITION', AUROPHARMA Price    1005.95
# Name: 2023-11-17 00:00:00, dtype: float64), (Timestamp('2023-11-20 00:00:00'), 'HOLD POSITION', AUROPHARMA Price    1002.65
# Name: 2023-11-20 00:00:00, dtype: float64), (Timestamp('2023-11-21 00:00:00'), 'HOLD POSITION', AUROPHARMA Price    1032.95
# Name: 2023-11-21 00:00:00, dtype: float64), (Timestamp('2023-11-22 00:00:00'), 'SELL', 1, AUROPHARMA Price    1055.5
# Name: 2023-11-22 00:00:00, dtype: float64), (Timestamp('2023-11-23 00:00:00'), 'BUY', 1, AUROPHARMA Price    1035.65
# Name: 2023-11-23 00:00:00, dtype: float64), (Timestamp('2023-11-24 00:00:00'), 'HOLD POSITION', AUROPHARMA Price    1032.9
# Name: 2023-11-24 00:00:00, dtype: float64), (Timestamp('2023-11-28 00:00:00'), 'HOLD POSITION', AUROPHARMA Price    1019.8
# Name: 2023-11-28 00:00:00, dtype: float64), (Timestamp('2023-11-29 00:00:00'), 'HOLD POSITION', AUROPHARMA Price    1020.9
# Name: 2023-11-29 00:00:00, dtype: float64), (Timestamp('2023-11-30 00:00:00'), 'SELL', 1, AUROPHARMA Price    1051.9
# Name: 2023-11-30 00:00:00, dtype: float64), (Timestamp('2023-12-01 00:00:00'), 'BUY', 1, AUROPHARMA Price    1042.55
# Name: 2023-12-01 00:00:00, dtype: float64), (Timestamp('2023-12-04 00:00:00'), 'HOLD POSITION', AUROPHARMA Price    1048.4
# Name: 2023-12-04 00:00:00, dtype: float64), (Timestamp('2023-12-05 00:00:00'), 'HOLD POSITION', AUROPHARMA Price    1031.45
# Name: 2023-12-05 00:00:00, dtype: float64), (Timestamp('2023-12-06 00:00:00'), 'HOLD POSITION', AUROPHARMA Price    1027.5
# Name: 2023-12-06 00:00:00, dtype: float64), (Timestamp('2023-12-07 00:00:00'), 'HOLD POSITION', AUROPHARMA Price    1030.5
# Name: 2023-12-07 00:00:00, dtype: float64), (Timestamp('2023-12-08 00:00:00'), 'HOLD POSITION', AUROPHARMA Price    1022.0
# Name: 2023-12-08 00:00:00, dtype: float64), (Timestamp('2023-12-11 00:00:00'), 'HOLD POSITION', AUROPHARMA Price    1011.3
# Name: 2023-12-11 00:00:00, dtype: float64), (Timestamp('2023-12-12 00:00:00'), 'HOLD POSITION', AUROPHARMA Price    1017.0
# Name: 2023-12-12 00:00:00, dtype: float64), (Timestamp('2023-12-13 00:00:00'), 'HOLD POSITION', AUROPHARMA Price    1043.45
# Name: 2023-12-13 00:00:00, dtype: float64), (Timestamp('2023-12-14 00:00:00'), 'HOLD POSITION', AUROPHARMA Price    1052.15
# Name: 2023-12-14 00:00:00, dtype: float64), (Timestamp('2023-12-15 00:00:00'), 'HOLD POSITION', AUROPHARMA Price    1032.9
# Name: 2023-12-15 00:00:00, dtype: float64), (Timestamp('2023-12-18 00:00:00'), 'HOLD POSITION', AUROPHARMA Price    1027.55
# Name: 2023-12-18 00:00:00, dtype: float64), (Timestamp('2023-12-19 00:00:00'), 'HOLD POSITION', AUROPHARMA Price    1038.5
# Name: 2023-12-19 00:00:00, dtype: float64), (Timestamp('2023-12-20 00:00:00'), 'HOLD POSITION', AUROPHARMA Price    1035.5
# Name: 2023-12-20 00:00:00, dtype: float64), (Timestamp('2023-12-21 00:00:00'), 'SELL', 1, AUROPHARMA Price    1094.0
# Name: 2023-12-21 00:00:00, dtype: float64), (Timestamp('2023-12-22 00:00:00'), 'BUY', 1, AUROPHARMA Price    1069.0
# Name: 2023-12-22 00:00:00, dtype: float64), (Timestamp('2023-12-26 00:00:00'), 'SELL', 1, AUROPHARMA Price    1066.45
# Name: 2023-12-26 00:00:00, dtype: float64), (Timestamp('2023-12-27 00:00:00'), 'BUY', 1, AUROPHARMA Price    1068.0
# Name: 2023-12-27 00:00:00, dtype: float64), (Timestamp('2023-12-28 00:00:00'), 'SELL', 1, AUROPHARMA Price    1095.15
# Name: 2023-12-28 00:00:00, dtype: float64), (Timestamp('2023-12-29 00:00:00'), 'BUY', 1, AUROPHARMA Price    1092.95
# Name: 2023-12-29 00:00:00, dtype: float64), (Timestamp('2024-01-01 00:00:00'), 'SELL', 1, AUROPHARMA Price    1090.3
# Name: 2024-01-01 00:00:00, dtype: float64), (Timestamp('2024-01-02 00:00:00'), 'BUY', 1, AUROPHARMA Price    1101.95
# Name: 2024-01-02 00:00:00, dtype: float64), (Timestamp('2024-01-03 00:00:00'), 'SELL', 1, AUROPHARMA Price    1099.55
# Name: 2024-01-03 00:00:00, dtype: float64), (Timestamp('2024-01-04 00:00:00'), 'BUY', 1, AUROPHARMA Price    1125.0
# Name: 2024-01-04 00:00:00, dtype: float64), (Timestamp('2024-01-05 00:00:00'), 'SELL', 1, AUROPHARMA Price    1126.5
# Name: 2024-01-05 00:00:00, dtype: float64), (Timestamp('2024-01-08 00:00:00'), 'BUY', 1, AUROPHARMA Price    1117.75
# Name: 2024-01-08 00:00:00, dtype: float64), (Timestamp('2024-01-09 00:00:00'), 'SELL', 1, AUROPHARMA Price    1126.25
# Name: 2024-01-09 00:00:00, dtype: float64), (Timestamp('2024-01-10 00:00:00'), 'BUY', 1, AUROPHARMA Price    1130.85
# Name: 2024-01-10 00:00:00, dtype: float64), (Timestamp('2024-01-11 00:00:00'), 'SELL', 1, AUROPHARMA Price    1113.0
# Name: 2024-01-11 00:00:00, dtype: float64), (Timestamp('2024-01-12 00:00:00'), 'BUY', 1, AUROPHARMA Price    1099.5
# Name: 2024-01-12 00:00:00, dtype: float64), (Timestamp('2024-01-15 00:00:00'), 'SELL', 1, AUROPHARMA Price    1154.85
# Name: 2024-01-15 00:00:00, dtype: float64), (Timestamp('2024-01-16 00:00:00'), 'BUY', 1, AUROPHARMA Price    1119.95
# Name: 2024-01-16 00:00:00, dtype: float64), (Timestamp('2024-01-17 00:00:00'), 'SELL', 1, AUROPHARMA Price    1090.75
# Name: 2024-01-17 00:00:00, dtype: float64), (Timestamp('2024-01-18 00:00:00'), 'BUY', 1, AUROPHARMA Price    1128.0
# Name: 2024-01-18 00:00:00, dtype: float64), (Timestamp('2024-01-19 00:00:00'), 'SELL', 1, AUROPHARMA Price    1150.0
# Name: 2024-01-19 00:00:00, dtype: float64), (Timestamp('2024-01-20 00:00:00'), 'BUY', 1, AUROPHARMA Price    1152.7
# Name: 2024-01-20 00:00:00, dtype: float64), (Timestamp('2024-01-23 00:00:00'), 'SELL', 1, AUROPHARMA Price    1136.5
# Name: 2024-01-23 00:00:00, dtype: float64), (Timestamp('2024-01-24 00:00:00'), 'BUY', 1, AUROPHARMA Price    1160.85
# Name: 2024-01-24 00:00:00, dtype: float64), (Timestamp('2024-01-25 00:00:00'), 'SELL', 1, AUROPHARMA Price    1143.7
# Name: 2024-01-25 00:00:00, dtype: float64), (Timestamp('2024-01-29 00:00:00'), 'BUY', 1, AUROPHARMA Price    1161.2
# Name: 2024-01-29 00:00:00, dtype: float64), (Timestamp('2024-01-30 00:00:00'), 'SELL', 1, AUROPHARMA Price    1163.0
# Name: 2024-01-30 00:00:00, dtype: float64), (Timestamp('2024-01-31 00:00:00'), 'BUY', 1, AUROPHARMA Price    1150.2
# Name: 2024-01-31 00:00:00, dtype: float64), (Timestamp('2024-02-01 00:00:00'), 'SELL', 1, AUROPHARMA Price    1072.75
# Name: 2024-02-01 00:00:00, dtype: float64), (Timestamp('2024-02-02 00:00:00'), 'BUY', 1, AUROPHARMA Price    1074.05
# Name: 2024-02-02 00:00:00, dtype: float64), (Timestamp('2024-02-05 00:00:00'), 'SELL', 1, AUROPHARMA Price    1027.0
# Name: 2024-02-05 00:00:00, dtype: float64), (Timestamp('2024-02-06 00:00:00'), 'BUY', 1, AUROPHARMA Price    1018.0
# Name: 2024-02-06 00:00:00, dtype: float64), (Timestamp('2024-02-07 00:00:00'), 'SELL', 1, AUROPHARMA Price    1011.0
# Name: 2024-02-07 00:00:00, dtype: float64), (Timestamp('2024-02-08 00:00:00'), 'BUY', 1, AUROPHARMA Price    1005.9
# Name: 2024-02-08 00:00:00, dtype: float64), (Timestamp('2024-02-09 00:00:00'), 'HOLD POSITION', AUROPHARMA Price    1000.0
# Name: 2024-02-09 00:00:00, dtype: float64), (Timestamp('2024-02-12 00:00:00'), 'HOLD POSITION', AUROPHARMA Price    1009.0
# Name: 2024-02-12 00:00:00, dtype: float64), (Timestamp('2024-02-13 00:00:00'), 'SELL', 1, AUROPHARMA Price    1021.1
# Name: 2024-02-13 00:00:00, dtype: float64), (Timestamp('2024-02-14 00:00:00'), 'BUY', 1, AUROPHARMA Price    997.85
# Name: 2024-02-14 00:00:00, dtype: float64), (Timestamp('2024-02-15 00:00:00'), 'SELL', 1, AUROPHARMA Price    1019.7
# Name: 2024-02-15 00:00:00, dtype: float64), (Timestamp('2024-02-16 00:00:00'), 'BUY', 1, AUROPHARMA Price    1034.95
# Name: 2024-02-16 00:00:00, dtype: float64), (Timestamp('2024-02-19 00:00:00'), 'SELL', 1, AUROPHARMA Price    1040.3
# Name: 2024-02-19 00:00:00, dtype: float64), (Timestamp('2024-02-20 00:00:00'), 'BUY', 1, AUROPHARMA Price    1051.6
# Name: 2024-02-20 00:00:00, dtype: float64), (Timestamp('2024-02-21 00:00:00'), 'SELL', 1, AUROPHARMA Price    1040.9
# Name: 2024-02-21 00:00:00, dtype: float64), (Timestamp('2024-02-22 00:00:00'), 'BUY', 1, AUROPHARMA Price    1044.65
# Name: 2024-02-22 00:00:00, dtype: float64), (Timestamp('2024-02-23 00:00:00'), 'SELL', 1, AUROPHARMA Price    1043.9
# Name: 2024-02-23 00:00:00, dtype: float64), (Timestamp('2024-02-26 00:00:00'), 'BUY', 1, AUROPHARMA Price    1041.6
# Name: 2024-02-26 00:00:00, dtype: float64), (Timestamp('2024-02-27 00:00:00'), 'SELL', 1, AUROPHARMA Price    1045.5
# Name: 2024-02-27 00:00:00, dtype: float64), (Timestamp('2024-02-28 00:00:00'), 'BUY', 1, AUROPHARMA Price    1027.0
# Name: 2024-02-28 00:00:00, dtype: float64), (Timestamp('2024-02-29 00:00:00'), 'HOLD POSITION', AUROPHARMA Price    1024.0
# Name: 2024-02-29 00:00:00, dtype: float64), (Timestamp('2024-03-01 00:00:00'), 'SELL', 1, AUROPHARMA Price    1030.05
# Name: 2024-03-01 00:00:00, dtype: float64), (Timestamp('2024-03-04 00:00:00'), 'BUY', 1, AUROPHARMA Price    1095.75
# Name: 2024-03-04 00:00:00, dtype: float64), (Timestamp('2024-03-05 00:00:00'), 'SELL', 1, AUROPHARMA Price    1088.0
# Name: 2024-03-05 00:00:00, dtype: float64), (Timestamp('2024-03-06 00:00:00'), 'BUY', 1, AUROPHARMA Price    1066.5
# Name: 2024-03-06 00:00:00, dtype: float64), (Timestamp('2024-03-07 00:00:00'), 'SELL', 1, AUROPHARMA Price    1062.75
# Name: 2024-03-07 00:00:00, dtype: float64), (Timestamp('2024-03-11 00:00:00'), 'BUY', 1, AUROPHARMA Price    1067.1
# Name: 2024-03-11 00:00:00, dtype: float64), (Timestamp('2024-03-12 00:00:00'), 'SELL', 1, AUROPHARMA Price    1050.0
# Name: 2024-03-12 00:00:00, dtype: float64), (Timestamp('2024-03-13 00:00:00'), 'BUY', 1, AUROPHARMA Price    1007.3
# Name: 2024-03-13 00:00:00, dtype: float64), (Timestamp('2024-03-14 00:00:00'), 'SELL', 1, AUROPHARMA Price    1017.1
# Name: 2024-03-14 00:00:00, dtype: float64), (Timestamp('2024-03-15 00:00:00'), 'BUY', 1, AUROPHARMA Price    1005.9
# Name: 2024-03-15 00:00:00, dtype: float64), (Timestamp('2024-03-18 00:00:00'), 'SELL', 1, AUROPHARMA Price    1025.0
# Name: 2024-03-18 00:00:00, dtype: float64), (Timestamp('2024-03-19 00:00:00'), 'BUY', 1, AUROPHARMA Price    991.1
# Name: 2024-03-19 00:00:00, dtype: float64), (Timestamp('2024-03-20 00:00:00'), 'HOLD POSITION', AUROPHARMA Price    1017.0
# Name: 2024-03-20 00:00:00, dtype: float64), (Timestamp('2024-03-21 00:00:00'), 'SELL', 1, AUROPHARMA Price    1029.45
# Name: 2024-03-21 00:00:00, dtype: float64), (Timestamp('2024-03-22 00:00:00'), 'BUY', 1, AUROPHARMA Price    1021.8
# Name: 2024-03-22 00:00:00, dtype: float64), (Timestamp('2024-03-26 00:00:00'), 'SELL', 1, AUROPHARMA Price    1052.65
# Name: 2024-03-26 00:00:00, dtype: float64), (Timestamp('2024-03-27 00:00:00'), 'BUY', 1, AUROPHARMA Price    1071.75
# Name: 2024-03-27 00:00:00, dtype: float64), (Timestamp('2024-03-28 00:00:00'), 'SELL', 1, AUROPHARMA Price    1104.8
# Name: 2024-03-28 00:00:00, dtype: float64), (Timestamp('2024-04-01 00:00:00'), 'BUY', 1, AUROPHARMA Price    1120.95
# Name: 2024-04-01 00:00:00, dtype: float64), (Timestamp('2024-04-02 00:00:00'), 'SELL', 1, AUROPHARMA Price    1109.0
# Name: 2024-04-02 00:00:00, dtype: float64), (Timestamp('2024-04-03 00:00:00'), 'BUY', 1, AUROPHARMA Price    1141.0
# Name: 2024-04-03 00:00:00, dtype: float64), (Timestamp('2024-04-04 00:00:00'), 'SELL', 1, AUROPHARMA Price    1132.0
# Name: 2024-04-04 00:00:00, dtype: float64), (Timestamp('2024-04-05 00:00:00'), 'BUY', 1, AUROPHARMA Price    1126.95
# Name: 2024-04-05 00:00:00, dtype: float64), (Timestamp('2024-04-08 00:00:00'), 'SELL', 1, AUROPHARMA Price    1123.0
# Name: 2024-04-08 00:00:00, dtype: float64), (Timestamp('2024-04-09 00:00:00'), 'BUY', 1, AUROPHARMA Price    1134.0
# Name: 2024-04-09 00:00:00, dtype: float64), (Timestamp('2024-04-10 00:00:00'), 'SELL', 1, AUROPHARMA Price    1113.45
# Name: 2024-04-10 00:00:00, dtype: float64), (Timestamp('2024-04-12 00:00:00'), 'BUY', 1, AUROPHARMA Price    1093.4
# Name: 2024-04-12 00:00:00, dtype: float64), (Timestamp('2024-04-15 00:00:00'), 'SELL', 1, AUROPHARMA Price    1089.95
# Name: 2024-04-15 00:00:00, dtype: float64), (Timestamp('2024-04-16 00:00:00'), 'BUY', 1, AUROPHARMA Price    1112.15
# Name: 2024-04-16 00:00:00, dtype: float64), (Timestamp('2024-04-18 00:00:00'), 'SELL', 1, AUROPHARMA Price    1115.05
# Name: 2024-04-18 00:00:00, dtype: float64), (Timestamp('2024-04-19 00:00:00'), 'BUY', 1, AUROPHARMA Price    1085.8
# Name: 2024-04-19 00:00:00, dtype: float64), (Timestamp('2024-04-22 00:00:00'), 'SELL', 1, AUROPHARMA Price    1081.05
# Name: 2024-04-22 00:00:00, dtype: float64), (Timestamp('2024-04-23 00:00:00'), 'BUY', 1, AUROPHARMA Price    1092.3
# Name: 2024-04-23 00:00:00, dtype: float64), (Timestamp('2024-04-24 00:00:00'), 'SELL', 1, AUROPHARMA Price    1085.85
# Name: 2024-04-24 00:00:00, dtype: float64), (Timestamp('2024-04-25 00:00:00'), 'BUY', 1, AUROPHARMA Price    1104.0
# Name: 2024-04-25 00:00:00, dtype: float64), (Timestamp('2024-04-26 00:00:00'), 'SELL', 1, AUROPHARMA Price    1137.25
# Name: 2024-04-26 00:00:00, dtype: float64), (Timestamp('2024-04-29 00:00:00'), 'BUY', 1, AUROPHARMA Price    1157.4
# Name: 2024-04-29 00:00:00, dtype: float64), (Timestamp('2024-04-30 00:00:00'), 'SELL', 1, AUROPHARMA Price    1160.65
# Name: 2024-04-30 00:00:00, dtype: float64), (Timestamp('2024-05-02 00:00:00'), 'BUY', 1, AUROPHARMA Price    1169.5
# Name: 2024-05-02 00:00:00, dtype: float64), (Timestamp('2024-05-03 00:00:00'), 'SELL', 1, AUROPHARMA Price    1158.25
# Name: 2024-05-03 00:00:00, dtype: float64), (Timestamp('2024-05-06 00:00:00'), 'BUY', 1, AUROPHARMA Price    1168.85
# Name: 2024-05-06 00:00:00, dtype: float64), (Timestamp('2024-05-07 00:00:00'), 'SELL', 1, AUROPHARMA Price    1127.95
# Name: 2024-05-07 00:00:00, dtype: float64), (Timestamp('2024-05-08 00:00:00'), 'BUY', 1, AUROPHARMA Price    1141.85
# Name: 2024-05-08 00:00:00, dtype: float64), (Timestamp('2024-05-09 00:00:00'), 'SELL', 1, AUROPHARMA Price    1124.45
# Name: 2024-05-09 00:00:00, dtype: float64), (Timestamp('2024-05-10 00:00:00'), 'BUY', 1, AUROPHARMA Price    1131.05
# Name: 2024-05-10 00:00:00, dtype: float64), (Timestamp('2024-05-13 00:00:00'), 'SELL', 1, AUROPHARMA Price    1182.55
# Name: 2024-05-13 00:00:00, dtype: float64), (Timestamp('2024-05-14 00:00:00'), 'BUY', 1, AUROPHARMA Price    1169.95
# Name: 2024-05-14 00:00:00, dtype: float64), (Timestamp('2024-05-15 00:00:00'), 'SELL', 1, AUROPHARMA Price    1164.0
# Name: 2024-05-15 00:00:00, dtype: float64), (Timestamp('2024-05-16 00:00:00'), 'BUY', 1, AUROPHARMA Price    1164.95
# Name: 2024-05-16 00:00:00, dtype: float64), (Timestamp('2024-05-17 00:00:00'), 'SELL', 1, AUROPHARMA Price    1175.0
# Name: 2024-05-17 00:00:00, dtype: float64), (Timestamp('2024-05-21 00:00:00'), 'BUY', 1, AUROPHARMA Price    1221.3
# Name: 2024-05-21 00:00:00, dtype: float64), (Timestamp('2024-05-22 00:00:00'), 'SELL', 1, AUROPHARMA Price    1234.0
# Name: 2024-05-22 00:00:00, dtype: float64), (Timestamp('2024-05-23 00:00:00'), 'BUY', 1, AUROPHARMA Price    1229.85
# Name: 2024-05-23 00:00:00, dtype: float64), (Timestamp('2024-05-24 00:00:00'), 'SELL', 1, AUROPHARMA Price    1233.0
# Name: 2024-05-24 00:00:00, dtype: float64), (Timestamp('2024-05-27 00:00:00'), 'BUY', 1, AUROPHARMA Price    1200.65
# Name: 2024-05-27 00:00:00, dtype: float64), (Timestamp('2024-05-28 00:00:00'), 'SELL', 1, AUROPHARMA Price    1214.15
# Name: 2024-05-28 00:00:00, dtype: float64), (Timestamp('2024-05-29 00:00:00'), 'BUY', 1, AUROPHARMA Price    1217.0
# Name: 2024-05-29 00:00:00, dtype: float64), (Timestamp('2024-05-30 00:00:00'), 'SELL', 1, AUROPHARMA Price    1206.0
# Name: 2024-05-30 00:00:00, dtype: float64), (Timestamp('2024-05-31 00:00:00'), 'BUY', 1, AUROPHARMA Price    1205.0
# Name: 2024-05-31 00:00:00, dtype: float64), (Timestamp('2024-06-03 00:00:00'), 'SELL', 1, AUROPHARMA Price    1235.35
# Name: 2024-06-03 00:00:00, dtype: float64), (Timestamp('2024-06-04 00:00:00'), 'BUY', 1, AUROPHARMA Price    1201.25
# Name: 2024-06-04 00:00:00, dtype: float64), (Timestamp('2024-06-05 00:00:00'), 'SELL', 1, AUROPHARMA Price    1269.4
# Name: 2024-06-05 00:00:00, dtype: float64), (Timestamp('2024-06-06 00:00:00'), 'BUY', 1, AUROPHARMA Price    1256.05
# Name: 2024-06-06 00:00:00, dtype: float64), (Timestamp('2024-06-07 00:00:00'), 'SELL', 1, AUROPHARMA Price    1268.05
# Name: 2024-06-07 00:00:00, dtype: float64), (Timestamp('2024-06-10 00:00:00'), 'BUY', 1, AUROPHARMA Price    1247.0
# Name: 2024-06-10 00:00:00, dtype: float64), (Timestamp('2024-06-11 00:00:00'), 'SELL', 1, AUROPHARMA Price    1258.0
# Name: 2024-06-11 00:00:00, dtype: float64), (Timestamp('2024-06-12 00:00:00'), 'BUY', 1, AUROPHARMA Price    1254.0
# Name: 2024-06-12 00:00:00, dtype: float64), (Timestamp('2024-06-13 00:00:00'), 'SELL', 1, AUROPHARMA Price    1255.85
# Name: 2024-06-13 00:00:00, dtype: float64), (Timestamp('2024-06-14 00:00:00'), 'BUY', 1, AUROPHARMA Price    1259.0
# Name: 2024-06-14 00:00:00, dtype: float64), (Timestamp('2024-06-18 00:00:00'), 'SELL', 1, AUROPHARMA Price    1241.7
# Name: 2024-06-18 00:00:00, dtype: float64), (Timestamp('2024-06-19 00:00:00'), 'BUY', 1, AUROPHARMA Price    1221.85
# Name: 2024-06-19 00:00:00, dtype: float64), (Timestamp('2024-06-20 00:00:00'), 'SELL', 1, AUROPHARMA Price    1242.95
# Name: 2024-06-20 00:00:00, dtype: float64), (Timestamp('2024-06-21 00:00:00'), 'BUY', 1, AUROPHARMA Price    1239.0
# Name: 2024-06-21 00:00:00, dtype: float64), (Timestamp('2024-06-24 00:00:00'), 'SELL', 1, AUROPHARMA Price    1221.3
# Name: 2024-06-24 00:00:00, dtype: float64), (Timestamp('2024-06-25 00:00:00'), 'BUY', 1, AUROPHARMA Price    1215.7
# Name: 2024-06-25 00:00:00, dtype: float64), (Timestamp('2024-06-26 00:00:00'), 'SELL', 1, AUROPHARMA Price    1197.15
# Name: 2024-06-26 00:00:00, dtype: float64), (Timestamp('2024-06-27 00:00:00'), 'BUY', 1, AUROPHARMA Price    1201.2
# Name: 2024-06-27 00:00:00, dtype: float64), (Timestamp('2024-06-28 00:00:00'), 'SELL', 1, AUROPHARMA Price    1216.95
# Name: 2024-06-28 00:00:00, dtype: float64), (Timestamp('2024-07-01 00:00:00'), 'BUY', 1, AUROPHARMA Price    1221.15
# Name: 2024-07-01 00:00:00, dtype: float64), (Timestamp('2024-07-02 00:00:00'), 'SELL', 1, AUROPHARMA Price    1219.55
# Name: 2024-07-02 00:00:00, dtype: float64)]

# %%
def trade_analysis(returns):
    
    plt.figure(figsize=(12, 6))
    plt.plot(returns, label='Cumulative PnL', color='blue')
    plt.title('Cumulative PnL', fontsize=16)
    plt.xlabel('Date', fontsize=14)
    plt.ylabel('PnL', fontsize=14)
    plt.grid(True)
    plt.legend()
    plt.tight_layout()

    total_return = (returns.iloc[-1] / returns.iloc[0]) 
    number_of_years = ((returns.index[-1] - returns.index[0]).days) / 365
    average_annual_return = ((total_return) ** (1 / number_of_years) - 1)*100
    print(f"The CAGR is: {average_annual_return}%")
    
    mean_returns = returns.pct_change().mean()*252*100
    print(f"The Average Annual Return is: {mean_returns}%")
    
    std_returns = returns.pct_change().std()*(252**0.5) * 100
    print(f"The Average Annual Percentage Risk is: {std_returns}%")
    
    sharpe = mean_returns / std_returns
    print(f"The Sharpe Ratio is: {sharpe}")



    plt.show()

# %%
def position_analysis(position_series):
    plt.figure(figsize=(12, 6))
    plt.plot(position_series, label='Position Size', color='blue')
    plt.title('Position Size over Time', fontsize=16)
    plt.xlabel('Date', fontsize=14)
    plt.ylabel('Position', fontsize=14)
    plt.grid(True)
    plt.legend()
    plt.tight_layout()
    plt.show()

# %%
position_analysis(position_series)

# %%
trade_analysis(cap_progression)
# Out:
# The CAGR is: 45.57506193457055%
# The Average Annual Return is: 40.28154379091643%
# The Average Annual Percentage Risk is: 18.388959893116986%
# The Sharpe Ratio is: 2.190528666387155
